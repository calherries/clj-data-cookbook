# %%
(require '[clojupyter.javascript.alpha :as cjp-js])
(require '[clojupyter.display :as display])
(require '[clojupyter.misc.helper :as helper])
(require '[clojure.data.json :as json])
# Out:
# nil

# %% [markdown]
# # 1.1 Reading data from a csv file

# %% [markdown]
# You can read data from a CSV file using the read_csv function. By default, it assumes that the fields are comma-separated.
#
# We're going to be looking some cyclist data from Montréal. Here's the original page (in French), but it's already included in this repository. We're using the data from 2012.
#
# This dataset is a list of how many people were on 7 different bike paths in Montreal, each day.

# %%
(helper/add-dependencies '[org.clojure/data.csv "1.0.0"])
(helper/add-dependencies '[metasoarous/oz "1.5.6"])
(require '[oz.notebook.clojupyter :as oz])
(require '[clojure.java.io :as io])
(require '[clojure.data.csv :as csv])
(require '[clojure.pprint :as pp])
# Out:
# nil

# %%
(def broken-data 
    (with-open [reader (io/reader "../data/bikes.csv")]
      (doall
        (csv/read-csv reader))))
# Out:
# #'user/broken-data

# %%
; Look at the first 3 rows
(take 3 broken-data)
# Out:
# (["Date;Berri 1;Br�beuf (donn�es non disponibles);C�te-Sainte-Catherine;Maisonneuve 1;Maisonneuve 2;du Parc;Pierre-Dupuy;Rachel1;St-Urbain (donn�es non disponibles)"] ["01/01/2012;35;;0;38;51;26;10;16;"] ["02/01/2012;83;;1;68;153;53;6;43;"])

# %% [markdown]
# You'll notice that this is totally broken! `io/reader` has a bunch of options that will let us fix that, though. Here we'll
#
# * change the column separator to a `;`
# * Set the encoding to `'ISO-8859-1'` (the default is `'UTF-8'`)

# %%
(def fixed-data
    (with-open [reader (io/reader "../data/bikes.csv" :encoding "ISO-8859-1")]
      (doall
        (csv/read-csv reader :separator \;))))
(->> fixed-data
     (take 5)
     pp/pprint)
# Out:
# (["Date"
#   "Berri 1"
#   "Brébeuf (données non disponibles)"
#   "Côte-Sainte-Catherine"
#   "Maisonneuve 1"
#   "Maisonneuve 2"
#   "du Parc"
#   "Pierre-Dupuy"
#   "Rachel1"
#   "St-Urbain (données non disponibles)"]
#  ["01/01/2012" "35" "" "0" "38" "51" "26" "10" "16" ""]
#  ["02/01/2012" "83" "" "1" "68" "153" "53" "6" "43" ""]
#  ["03/01/2012" "135" "" "2" "104" "248" "89" "3" "58" ""]
#  ["04/01/2012" "144" "" "1" "116" "318" "111" "8" "61" ""])
# nil

# %%
(defn blank->nil [s]
  (when-not (clojure.string/blank? s) s))

(defn csv-data->maps [csv-data]
  (map zipmap
       (->> (first csv-data) ;; First row is the header
            (map keyword) ;; Drop if you want string keys instead
            repeat)
       (->> (rest csv-data)
            (map #(map blank->nil %))))) ;; Drop if you want blank strings to stay

(def fixed-df (csv-data->maps fixed-data))
(->> fixed-df
     (take 5)
     pp/pprint)
# Out:
# ({:du Parc "26",
#   :Rachel1 "16",
#   :Pierre-Dupuy "10",
#   :Berri 1 "35",
#   :Maisonneuve 1 "38",
#   :Brébeuf (données non disponibles) nil,
#   :Date "01/01/2012",
#   :Côte-Sainte-Catherine "0",
#   :St-Urbain (données non disponibles) nil,
#   :Maisonneuve 2 "51"}
#  {:du Parc "53",
#   :Rachel1 "43",
#   :Pierre-Dupuy "6",
#   :Berri 1 "83",
#   :Maisonneuve 1 "68",
#   :Brébeuf (données non disponibles) nil,
#   :Date "02/01/2012",
#   :Côte-Sainte-Catherine "1",
#   :St-Urbain (données non disponibles) nil,
#   :Maisonneuve 2 "153"}
#  {:du Parc "89",
#   :Rachel1 "58",
#   :Pierre-Dupuy "3",
#   :Berri 1 "135",
#   :Maisonneuve 1 "104",
#   :Brébeuf (données non disponibles) nil,
#   :Date "03/01/2012",
#   :Côte-Sainte-Catherine "2",
#   :St-Urbain (données non disponibles) nil,
#   :Maisonneuve 2 "248"}
#  {:du Parc "111",
#   :Rachel1 "61",
#   :Pierre-Dupuy "8",
#   :Berri 1 "144",
#   :Maisonneuve 1 "116",
#   :Brébeuf (données non disponibles) nil,
#   :Date "04/01/2012",
#   :Côte-Sainte-Catherine "1",
#   :St-Urbain (données non disponibles) nil,
#   :Maisonneuve 2 "318"}
#  {:du Parc "97",
#   :Rachel1 "95",
#   :Pierre-Dupuy "13",
#   :Berri 1 "197",
#   :Maisonneuve 1 "124",
#   :Brébeuf (données non disponibles) nil,
#   :Date "05/01/2012",
#   :Côte-Sainte-Catherine "2",
#   :St-Urbain (données non disponibles) nil,
#   :Maisonneuve 2 "330"})
# nil

# %% [markdown]
# Finally, for a result which is a sequence of maps (like the above), you can use clojure.pprint/print-table to print it as a table:

# %%
(->> fixed-df
     (take 5)
     (map #(into {} (take 7 %)))
     pp/print-table)
# Out:
# | :du Parc | :Rachel1 | :Pierre-Dupuy | :Berri 1 | :Maisonneuve 1 | :Brébeuf (données non disponibles) |      :Date |
# |----------+----------+---------------+----------+----------------+------------------------------------+------------|
# |       26 |       16 |            10 |       35 |             38 |                                    | 01/01/2012 |
# |       53 |       43 |             6 |       83 |             68 |                                    | 02/01/2012 |
# |       89 |       58 |             3 |      135 |            104 |                                    | 03/01/2012 |
# |      111 |       61 |             8 |      144 |            116 |                                    | 04/01/2012 |
# |       97 |       95 |            13 |      197 |            124 |                                    | 05/01/2012 |
# nil

# %% [markdown]
# * Parse the dates in the 'Date' column
# * Tell it that our dates have the day first instead of the month first
# * Set the index to be the 'Date' column

# %%
(helper/add-dependencies '[clojure.java-time "0.3.2"])
(require '[java-time :as t])
(require '[clojure.edn :as edn])
# Out:
# nil

# %% [markdown]
# You can use the edn reader to parse numbers. This has the benefit of giving you floats or Bignums when needed, too.

# %%
(defn col-parser [col-key]
    (if (= :Date col-key) 
         (partial t/local-date "dd/MM/yyyy") 
         edn/read-string))

(def parsed-df
    (->> fixed-df
         (map #(into {} (map (fn [[k v]] [k ((col-parser k) v)]) %))))) ;; Apply each parser to columns

(->> parsed-df
     (take 5)
     (map #(into {} (take 7 %)))
     pp/print-table)
# Out:
# | :du Parc | :Rachel1 | :Pierre-Dupuy | :Berri 1 | :Maisonneuve 1 | :Brébeuf (données non disponibles) |      :Date |
# |----------+----------+---------------+----------+----------------+------------------------------------+------------|
# |       26 |       16 |            10 |       35 |             38 |                                    | 2012-01-01 |
# |       53 |       43 |             6 |       83 |             68 |                                    | 2012-01-02 |
# |       89 |       58 |             3 |      135 |            104 |                                    | 2012-01-03 |
# | 2012-09-12 |     6349 |
# | 2012-09-13 |     6520 |
# | 2012-09-14 |     5216 |
# | 2012-09-15 |     3341 |
# | 2012-09-16 |     3635 |
# | 2012-09-17 |     5299 |
# | 2012-09-18 |     2530 |
# | 2012-09-19 |     4653 |
# | 2012-09-20 |     5260 |
# | 2012-09-21 |     4022 |
# | 2012-09-22 |     1521 |
# | 2012-09-23 |     2314 |
# | 2012-09-24 |     4553 |
# | 2012-09-25 |     5038 |
# | 2012-09-26 |     3948 |
# | 2012-09-27 |     5119 |
# | 2012-09-28 |     4652 |
# | 2012-09-29 |     1896 |
# | 2012-09-30 |      876 |
# | 2012-10-01 |     3255 |
# | 2012-10-02 |     5139 |
# | 2012-10-03 |     4685 |
# | 2012-10-04 |     4034 |
# | 2012-10-05 |     4151 |
# | 2012-10-06 |     1304 |
# | 2012-10-07 |     1580 |
# | 2012-10-08 |     1854 |
# | 2012-10-09 |     4787 |
# | 2012-10-10 |     3115 |
# | 2012-10-11 |     3746 |
# | 2012-10-12 |     3169 |
# | 2012-10-13 |     1783 |
# | 2012-10-14 |      587 |
# | 2012-10-15 |     3292 |
# | 2012-10-16 |     3739 |
# | 2012-10-17 |     4098 |
# | 2012-10-18 |     4671 |
# | 2012-10-19 |     1313 |
# | 2012-10-20 |     2011 |
# | 2012-10-21 |     1277 |
# | 2012-10-22 |     3650 |
# | 2012-10-23 |     4177 |
# | 2012-10-24 |     3744 |
# | 2012-10-25 |     3735 |
# | 2012-10-26 |     4290 |
# | 2012-10-27 |     1857 |
# | 2012-10-28 |     1310 |
# | 2012-10-29 |     2919 |
# | 2012-10-30 |     2887 |
# | 2012-10-31 |     2634 |
# | 2012-11-01 |     2405 |
# | 2012-11-02 |     1582 |
# | 2012-11-03 |      844 |
# | 2012-11-04 |      966 |
# | 2012-11-05 |     2247 |
# nil

# %% [markdown]
# # 1.3 Plotting a column

# %% [markdown]
# We can see that, unsurprisingly, not many people are biking in January, February, and March,

# %%
(def line-plot
  "Transform data for visualization"
  {:mark     "line"
   :data     {:values (map #(update % :Date t/format) parsed-df)}
   :encoding {:x     {:field :Date
                      :type "temporal"}
              :y     {:field (keyword "Berri 1")
                      :type "quantitative"}}
   :width 500})
(oz/view! line-plot)
# Out:
# <div>
#   <div id='uuid-4e84646f-1868-473c-bca6-0c519d4435d6'></div>
#   <script>
#   requirejs.config({
#     baseUrl: 'https://cdn.jsdelivr.net/npm/',
#     paths: {
#       'vega-embed':  'vega-embed@3?noext',
#       'vega-lib': 'vega-lib?noext',
#       'vega-lite': 'vega-lite@2?noext',
#       'vega': 'vega@3?noext'
#     }
#   });
#   require(['vega-embed'], function(vegaEmbed) {
#     let spec = {"mark":"line","data":{"values":[{"du Parc":26,"Rachel1":16,"Pierre-Dupuy":10,"Berri 1":35,"Maisonneuve 1":38,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-01","C\u00f4te-Sainte-Catherine":0,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":51},{"du Parc":53,"Rachel1":43,"Pierre-Dupuy":6,"Berri 1":83,"Maisonneuve 1":68,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-02","C\u00f4te-Sainte-Catherine":1,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":153},{"du Parc":89,"Rachel1":58,"Pierre-Dupuy":3,"Berri 1":135,"Maisonneuve 1":104,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-03","C\u00f4te-Sainte-Catherine":2,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":248},{"du Parc":111,"Rachel1":61,"Pierre-Dupuy":8,"Berri 1":144,"Maisonneuve 1":116,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-04","C\u00f4te-Sainte-Catherine":1,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":318},{"du Parc":97,"Rachel1":95,"Pierre-Dupuy":13,"Berri 1":197,"Maisonneuve 1":124,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-05","C\u00f4te-Sainte-Catherine":2,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":330},{"du Parc":86,"Rachel1":75,"Pierre-Dupuy":4,"Berri 1":146,"Maisonneuve 1":98,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-06","C\u00f4te-Sainte-Catherine":0,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":244},{"du Parc":53,"Rachel1":54,"Pierre-Dupuy":6,"Berri 1":98,"Maisonneuve 1":80,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-07","C\u00f4te-Sainte-Catherine":2,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":108},{"du Parc":64,"Rachel1":63,"Pierre-Dupuy":11,"Berri 1":95,"Maisonneuve 1":62,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-08","C\u00f4te-Sainte-Catherine":1,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":98},{"du Parc":198,"Rachel1":173,"Pierre-Dupuy":12,"Berri 1":244,"Maisonneuve 1":165,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-09","C\u00f4te-Sainte-Catherine":2,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":432},{"du Parc":275,"Rachel1":241,"Pierre-Dupuy":18,"Berri 1":397,"Maisonneuve 1":238,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-10","C\u00f4te-Sainte-Catherine":3,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":563},{"du Parc":258,"Rachel1":194,"Pierre-Dupuy":12,"Berri 1":273,"Maisonneuve 1":182,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-11","C\u00f4te-Sainte-Catherine":0,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":443},{"du Parc":137,"Rachel1":63,"Pierre-Dupuy":9,"Berri 1":157,"Maisonneuve 1":134,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-12","C\u00f4te-Sainte-Catherine":1,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":261},{"du Parc":64,"Rachel1":0,"Pierre-Dupuy":2,"Berri 1":75,"Maisonneuve 1":41,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-13","C\u00f4te-Sainte-Catherine":0,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":105},{"du Parc":19,"Rachel1":1,"Pierre-Dupuy":0,"Berri 1":32,"Maisonneuve 1":54,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-14","C\u00f4te-Sainte-Catherine":0,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":56},{"du Parc":18,"Rachel1":0,"Pierre-Dupuy":0,"Berri 1":54,"Maisonneuve 1":33,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-15","C\u00f4te-Sainte-Catherine":0,"St-Urbain (donn\u00e9es non disponibles)":null,"Maisonneuve 2":60},{"du Parc":137,"Rachel1":0,"Pierre-Dupuy":1,"Berri 1":168,"Maisonneuve 1":136,"Br\u00e9beuf (donn\u00e9es non disponibles)":null,"Date":"2012-01-16","C\u00f4te-Sainte-Catherine":2,"Maisonneuve 2":312},{"du Parc":74,"Rachel1": ...

# %% [markdown]
# We can also plot all the columns just as easily. We'll make it a little bigger, too.
# You can see that it's more squished together, but all the bike paths behave basically the same -- if it's a bad day for cyclists, it's a bad day everywhere.

# %%
;; prepare dataframe for multiple categories
(def value-vars (remove #{:Date} (keys (first parsed-df))))

(defn melt 
    [m key-var value-vars]
    (mapcat (fn [m] 
              (for [v value-vars]
                {key-var (key-var m)
                 :value (v m)
                 :variable v}))
             m))

(def melted-df (melt parsed-df :Date value-vars))
(->> melted-df
     (take 10)
     pp/print-table)
# Out:
# |      :Date | :value |                            :variable |
# |------------+--------+--------------------------------------|
# | 2012-01-01 |     26 |                             :du Parc |
# | 2012-01-01 |     16 |                             :Rachel1 |
# | 2012-01-01 |     10 |                        :Pierre-Dupuy |
# | 2012-01-01 |     35 |                             :Berri 1 |
# | 2012-01-01 |     38 |                       :Maisonneuve 1 |
# | 2012-01-01 |        |   :Brébeuf (données non disponibles) |
# | 2012-01-01 |      0 |               :Côte-Sainte-Catherine |
# | 2012-01-01 |        | :St-Urbain (données non disponibles) |
# | 2012-01-01 |     51 |                       :Maisonneuve 2 |
# | 2012-01-02 |     53 |                             :du Parc |
# nil

# %%
(def line-plot
  "Transform data for visualization"
  {:mark     "line"
   :data     {:values (map #(update % :Date t/format) melted-df)}
   :encoding {:x     {:field :Date
                      :type "temporal"}
              :y     {:field :value
                      :type "quantitative"}
              :color {:field :variable
                      :type "nominal"}}
   :width 500})
(oz/view! line-plot)
# Out:
# <div>
#   <div id='uuid-c8ba7c90-3dfc-493b-b52d-b62bb5457289'></div>
#   <script>
#   requirejs.config({
#     baseUrl: 'https://cdn.jsdelivr.net/npm/',
#     paths: {
#       'vega-embed':  'vega-embed@3?noext',
#       'vega-lib': 'vega-lib?noext',
#       'vega-lite': 'vega-lite@2?noext',
#       'vega': 'vega@3?noext'
#     }
#   });
#   require(['vega-embed'], function(vegaEmbed) {
#     let spec = {"mark":"line","data":{"values":[{"Date":"2012-01-01","value":26,"variable":"du Parc"},{"Date":"2012-01-01","value":16,"variable":"Rachel1"},{"Date":"2012-01-01","value":10,"variable":"Pierre-Dupuy"},{"Date":"2012-01-01","value":35,"variable":"Berri 1"},{"Date":"2012-01-01","value":38,"variable":"Maisonneuve 1"},{"Date":"2012-01-01","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date":"2012-01-01","value":0,"variable":"C\u00f4te-Sainte-Catherine"},{"Date":"2012-01-01","value":null,"variable":"St-Urbain (donn\u00e9es non disponibles)"},{"Date":"2012-01-01","value":51,"variable":"Maisonneuve 2"},{"Date":"2012-01-02","value":53,"variable":"du Parc"},{"Date":"2012-01-02","value":43,"variable":"Rachel1"},{"Date":"2012-01-02","value":6,"variable":"Pierre-Dupuy"},{"Date":"2012-01-02","value":83,"variable":"Berri 1"},{"Date":"2012-01-02","value":68,"variable":"Maisonneuve 1"},{"Date":"2012-01-02","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date":"2012-01-02","value":1,"variable":"C\u00f4te-Sainte-Catherine"},{"Date":"2012-01-02","value":null,"variable":"St-Urbain (donn\u00e9es non disponibles)"},{"Date":"2012-01-02","value":153,"variable":"Maisonneuve 2"},{"Date":"2012-01-03","value":89,"variable":"du Parc"},{"Date":"2012-01-03","value":58,"variable":"Rachel1"},{"Date":"2012-01-03","value":3,"variable":"Pierre-Dupuy"},{"Date":"2012-01-03","value":135,"variable":"Berri 1"},{"Date":"2012-01-03","value":104,"variable":"Maisonneuve 1"},{"Date":"2012-01-03","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date":"2012-01-03","value":2,"variable":"C\u00f4te-Sainte-Catherine"},{"Date":"2012-01-03","value":null,"variable":"St-Urbain (donn\u00e9es non disponibles)"},{"Date":"2012-01-03","value":248,"variable":"Maisonneuve 2"},{"Date":"2012-01-04","value":111,"variable":"du Parc"},{"Date":"2012-01-04","value":61,"variable":"Rachel1"},{"Date":"2012-01-04","value":8,"variable":"Pierre-Dupuy"},{"Date":"2012-01-04","value":144,"variable":"Berri 1"},{"Date":"2012-01-04","value":116,"variable":"Maisonneuve 1"},{"Date":"2012-01-04","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date":"2012-01-04","value":1,"variable":"C\u00f4te-Sainte-Catherine"},{"Date":"2012-01-04","value":null,"variable":"St-Urbain (donn\u00e9es non disponibles)"},{"Date":"2012-01-04","value":318,"variable":"Maisonneuve 2"},{"Date":"2012-01-05","value":97,"variable":"du Parc"},{"Date":"2012-01-05","value":95,"variable":"Rachel1"},{"Date":"2012-01-05","value":13,"variable":"Pierre-Dupuy"},{"Date":"2012-01-05","value":197,"variable":"Berri 1"},{"Date":"2012-01-05","value":124,"variable":"Maisonneuve 1"},{"Date":"2012-01-05","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date":"2012-01-05","value":2,"variable":"C\u00f4te-Sainte-Catherine"},{"Date":"2012-01-05","value":null,"variable":"St-Urbain (donn\u00e9es non disponibles)"},{"Date":"2012-01-05","value":330,"variable":"Maisonneuve 2"},{"Date":"2012-01-06","value":86,"variable":"du Parc"},{"Date":"2012-01-06","value":75,"variable":"Rachel1"},{"Date":"2012-01-06","value":4,"variable":"Pierre-Dupuy"},{"Date":"2012-01-06","value":146,"variable":"Berri 1"},{"Date":"2012-01-06","value":98,"variable":"Maisonneuve 1"},{"Date":"2012-01-06","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date":"2012-01-06","value":0,"variable":"C\u00f4te-Sainte-Catherine"},{"Date":"2012-01-06","value":null,"variable":"St-Urbain (donn\u00e9es non disponibles)"},{"Date":"2012-01-06","value":244,"variable":"Maisonneuve 2"},{"Date":"2012-01-07","value":53,"variable":"du Parc"},{"Date":"2012-01-07","value":54,"variable":"Rachel1"},{"Date":"2012-01-07","value":6,"variable":"Pierre-Dupuy"},{"Date":"2012-01-07","value":98,"variable":"Berri 1"},{"Date":"2012-01-07","value":80,"variable":"Maisonneuve 1"},{"Date":"2012-01-07","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date" ...

# %% [markdown]
# # 1.4 Putting all that together

# %%
;; read data in
(def fixed-data
    (with-open [reader (io/reader "../data/bikes.csv" :encoding "ISO-8859-1")]
      (doall
        (csv/read-csv reader :separator \;))))

(defn blank->nil [s]
  (when-not (clojure.string/blank? s) s))

(defn csv-data->maps [csv-data]
  (map zipmap
       (->> (first csv-data) ;; First row is the header
            (map keyword) ;; Drop if you want string keys instead
            repeat)
       (->> (rest csv-data)
            (map #(map blank->nil %))))) ;; Drop if you want blank strings to stay

(def fixed-df (csv-data->maps fixed-data))

(defn col-parser [col-key]
    (if (= :Date col-key) 
         (partial t/local-date "dd/MM/yyyy") 
         edn/read-string))

(def parsed-df
    (->> fixed-df
         (map #(into {} (map (fn [[k v]] 
                                 [k ((col-parser k) v)])  ;; Apply each parser to the values of the column
                             %)))))

;; prepare dataframe for multiple categories
(def value-vars (remove #{:Date} (keys (first parsed-df))))

(defn melt 
    [m key-var value-vars]
    (mapcat (fn [m] 
              (for [v value-vars]
                {key-var (key-var m)
                 :value (v m)
                 :variable v}))
             m))

(def melted-df (melt parsed-df :Date value-vars))

(def line-plot
  "Transform data for visualization"
  {:mark     "line"
   :data     {:values (map #(update % :Date t/format) melted-df)}
   :encoding {:x     {:field :Date
                      :type "temporal"}
              :y     {:field :value
                      :type "quantitative"}
              :color {:field :variable
                      :type "nominal"}}
   :height 500
   :width 800})
(oz/view! line-plot)
# Out:
# <div>
#   <div id='uuid-8135db96-3918-4bea-a2e6-ffac92e7b19c'></div>
#   <script>
#   requirejs.config({
#     baseUrl: 'https://cdn.jsdelivr.net/npm/',
#     paths: {
#       'vega-embed':  'vega-embed@3?noext',
#       'vega-lib': 'vega-lib?noext',
#       'vega-lite': 'vega-lite@2?noext',
#       'vega': 'vega@3?noext'
#     }
#   });
#   require(['vega-embed'], function(vegaEmbed) {
#     let spec = {"mark":"line","data":{"values":[{"Date":"2012-01-01","value":26,"variable":"du Parc"},{"Date":"2012-01-01","value":16,"variable":"Rachel1"},{"Date":"2012-01-01","value":10,"variable":"Pierre-Dupuy"},{"Date":"2012-01-01","value":35,"variable":"Berri 1"},{"Date":"2012-01-01","value":38,"variable":"Maisonneuve 1"},{"Date":"2012-01-01","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date":"2012-01-01","value":0,"variable":"C\u00f4te-Sainte-Catherine"},{"Date":"2012-01-01","value":null,"variable":"St-Urbain (donn\u00e9es non disponibles)"},{"Date":"2012-01-01","value":51,"variable":"Maisonneuve 2"},{"Date":"2012-01-02","value":53,"variable":"du Parc"},{"Date":"2012-01-02","value":43,"variable":"Rachel1"},{"Date":"2012-01-02","value":6,"variable":"Pierre-Dupuy"},{"Date":"2012-01-02","value":83,"variable":"Berri 1"},{"Date":"2012-01-02","value":68,"variable":"Maisonneuve 1"},{"Date":"2012-01-02","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date":"2012-01-02","value":1,"variable":"C\u00f4te-Sainte-Catherine"},{"Date":"2012-01-02","value":null,"variable":"St-Urbain (donn\u00e9es non disponibles)"},{"Date":"2012-01-02","value":153,"variable":"Maisonneuve 2"},{"Date":"2012-01-03","value":89,"variable":"du Parc"},{"Date":"2012-01-03","value":58,"variable":"Rachel1"},{"Date":"2012-01-03","value":3,"variable":"Pierre-Dupuy"},{"Date":"2012-01-03","value":135,"variable":"Berri 1"},{"Date":"2012-01-03","value":104,"variable":"Maisonneuve 1"},{"Date":"2012-01-03","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date":"2012-01-03","value":2,"variable":"C\u00f4te-Sainte-Catherine"},{"Date":"2012-01-03","value":null,"variable":"St-Urbain (donn\u00e9es non disponibles)"},{"Date":"2012-01-03","value":248,"variable":"Maisonneuve 2"},{"Date":"2012-01-04","value":111,"variable":"du Parc"},{"Date":"2012-01-04","value":61,"variable":"Rachel1"},{"Date":"2012-01-04","value":8,"variable":"Pierre-Dupuy"},{"Date":"2012-01-04","value":144,"variable":"Berri 1"},{"Date":"2012-01-04","value":116,"variable":"Maisonneuve 1"},{"Date":"2012-01-04","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date":"2012-01-04","value":1,"variable":"C\u00f4te-Sainte-Catherine"},{"Date":"2012-01-04","value":null,"variable":"St-Urbain (donn\u00e9es non disponibles)"},{"Date":"2012-01-04","value":318,"variable":"Maisonneuve 2"},{"Date":"2012-01-05","value":97,"variable":"du Parc"},{"Date":"2012-01-05","value":95,"variable":"Rachel1"},{"Date":"2012-01-05","value":13,"variable":"Pierre-Dupuy"},{"Date":"2012-01-05","value":197,"variable":"Berri 1"},{"Date":"2012-01-05","value":124,"variable":"Maisonneuve 1"},{"Date":"2012-01-05","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date":"2012-01-05","value":2,"variable":"C\u00f4te-Sainte-Catherine"},{"Date":"2012-01-05","value":null,"variable":"St-Urbain (donn\u00e9es non disponibles)"},{"Date":"2012-01-05","value":330,"variable":"Maisonneuve 2"},{"Date":"2012-01-06","value":86,"variable":"du Parc"},{"Date":"2012-01-06","value":75,"variable":"Rachel1"},{"Date":"2012-01-06","value":4,"variable":"Pierre-Dupuy"},{"Date":"2012-01-06","value":146,"variable":"Berri 1"},{"Date":"2012-01-06","value":98,"variable":"Maisonneuve 1"},{"Date":"2012-01-06","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date":"2012-01-06","value":0,"variable":"C\u00f4te-Sainte-Catherine"},{"Date":"2012-01-06","value":null,"variable":"St-Urbain (donn\u00e9es non disponibles)"},{"Date":"2012-01-06","value":244,"variable":"Maisonneuve 2"},{"Date":"2012-01-07","value":53,"variable":"du Parc"},{"Date":"2012-01-07","value":54,"variable":"Rachel1"},{"Date":"2012-01-07","value":6,"variable":"Pierre-Dupuy"},{"Date":"2012-01-07","value":98,"variable":"Berri 1"},{"Date":"2012-01-07","value":80,"variable":"Maisonneuve 1"},{"Date":"2012-01-07","value":null,"variable":"Br\u00e9beuf (donn\u00e9es non disponibles)"},{"Date" ...
